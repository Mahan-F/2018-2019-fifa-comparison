# %%
import pandas as pd
import time
import matplotlib.pyplot as plt

# %%
pd.options.mode.chained_assignment = None  # default='warn'

plt.close('all')

# Removing the un-needed columns
columnsNotIncluded = ['Unnamed: 0', 'Joined', 'Photo', 'Flag', 'Club Logo']
column_dtypes = {
    'Age': 'int64',
    'Overall': 'int64',
    'Potential': 'int64'
}

# reading csv file
data18 = pd.read_csv("2018.csv", dtype=column_dtypes, usecols=lambda column: column not in columnsNotIncluded, low_memory=False)
data19 = pd.read_csv("2019.csv", dtype=column_dtypes, usecols=lambda column: column not in columnsNotIncluded, low_memory=False)

MAX = len(data18.index)

# Renaming columns to match
data18.rename(columns={'Preferred Positions': 'Position'}, inplace=True)

# Strip trailing whitespace from end of Positions
data18['Position'] = data18['Position'].str.strip()

# Convert the Value columns to only numbers so they can be compared
data19['Value'] = data19['Value'].map(lambda x: x.lstrip('€'))
data18['Value'] = data18['Value'].map(lambda x: x.lstrip('€'))

data18['Value'] = (data18['Value'].replace(r'[KM]+$', '', regex=True).astype(float) *
                   data18['Value'].str.extract(r'[\d\.]+([KM]+)', expand=False).fillna(1)
                   .replace(['K', 'M'], [10 ** 3, 10 ** 6]).astype(int))

data19['Value'] = (data19['Value'].replace(r'[KM]+$', '', regex=True).astype(float) *
                   data19['Value'].str.extract(r'[\d\.]+([KM]+)', expand=False).fillna(1)
                   .replace(['K', 'M'], [10 ** 3, 10 ** 6]).astype(int))

# Join the 2 datasets together for fast comparisons
data_joined = data18.set_index('ID').join(data19.set_index('ID'), how='left', lsuffix="_18", rsuffix="_19")

# %%
result = data_joined.loc[(data_joined['Name_19'].isnull() != True)]  # All players that are not retired

result['Overall Difference'] = result['Overall_19'] - result['Overall_18']
result = result.sort_values(by=['Overall Difference'], ascending=False)

most_increase = result.head(10)
most_decrease = result.tail(10).iloc[::-1]

print('\nList of players with the most increase in Overall: ')
print(most_increase[['Name_19', 'Overall Difference']])
print('\nList of players with the most decrease in Overall: ')
print(most_decrease[['Name_19', 'Overall Difference']])

overall_joined = pd.concat([most_increase, most_decrease])

overall_joined.set_index('Name_19')['Overall Difference'].plot.bar();
# Out:
# List of players with the most increase in Overall:
#                Name_19  Overall Difference
# ID
# 236527      S. Cáseres                20.0
# 229880  A. Wan-Bissaka                19.0
# 240679  T. Koopmeiners                17.0
# 233267       M. Turner                17.0
# 236522     E. Brignola                17.0
# 229406     João Novais                16.0
# 241184    Junior Firpo                16.0
# 235794          E. Eze                16.0
# 235863      M. Varnier                15.0
# 224263        J. Kenny                15.0
#
# List of players with the most decrease in Overall:
#              Name_19  Overall Difference
# ID
# 179930  S. Pawłowski                -9.0
# 163824   A. Williams                -8.0
# 137510  A. Kruiswijk                -8.0
# 6826        G. Barry                -7.0
# 168630       M. Dabo                -7.0
# 189772   M. Woolford                -7.0
# 225341  David García                -7.0
# 183070       W. Hesl                -7.0
# 138083       N. Hunt                -7.0
# 138110   Bruno Alves                -7.0

# %%
print('In which position are the oldest players (eg. Goalkeepers)?')

oldest18 = data18.loc[data18['Age'] == data18['Age'].max()]
print('Oldest Player of 2018 is ' + oldest18.iloc[0]['Name'] + ' with the age of ' + str(oldest18.iloc[0]['Age']) +
      ' with the position: ' + oldest18.iloc[0]['Position'])

oldest19 = data19.loc[data19['Age'] == data19['Age'].max()]
print('Oldest Player of 2019 is ' + oldest19.iloc[0]['Name'] + ' with the age of ' +
      str(oldest19.iloc[0]['Age']) + ' with the position: ' + oldest19.iloc[0]['Position'])
# Out:
# In which position are the oldest players (eg. Goalkeepers)?
# Oldest Player of 2018 is B. Richardson with the age of 47 with the position: GK
# Oldest Player of 2019 is O. Pérez with the age of 45 with the position: GK

# %%
print('Which players had the most change in value and why? is it based on their overall improvement?')

result = data_joined.loc[(data_joined['Name_19'].isnull() != True)]  # All players that are not retired

result['Overall Difference'] = result['Overall_19'] - result['Overall_18']
result['Value Difference'] = result['Value_19'] - result['Value_18']
result = result.sort_values(by=['Value Difference'], ascending=False)

most_increase = result.head(10)
most_decrease = result.tail(10).iloc[::-1]

print('\nList of players with the most increase in value: ')
print(most_increase[['Name_19', 'Value Difference', 'Overall Difference']])
print('\nList of players with the most decrease in value: ')
print(most_decrease[['Name_19', 'Value Difference', 'Overall Difference']])

most_increase.set_index('Name_19')['Overall Difference'].plot.bar();
# Out:
# Which players had the most change in value and why? is it based on their overall improvement?
#
# List of players with the most increase in value:
#                     Name_19  Value Difference  Overall Difference
# ID
# 231747            K. Mbappé        39500000.0                 5.0
# 232363          M. Škriniar        39500000.0                11.0
# 209331             M. Salah        37000000.0                 5.0
# 223848  S. Milinković-Savić        30500000.0                 5.0
# 188152                Oscar        30500000.0                 0.0
# 205600            S. Umtiti        27500000.0                 4.0
# 202652          R. Sterling        27000000.0                 4.0
# 222492              L. Sané        26500000.0                 4.0
# 231866                Rodri        26300000.0                12.0
# 192387          C. Immobile        26000000.0                 5.0
#
# List of players with the most decrease in value:
#                   Name_19  Value Difference  Overall Difference
# ID
# 184941         A. Sánchez       -30000000.0                -4.0
# 189509             Thiago       -25000000.0                -2.0
# 167495           M. Neuer       -23000000.0                -3.0
# 9014            A. Robben       -20500000.0                -4.0
# 167664         G. Higuaín       -20000000.0                -2.0
# 162895      Cesc Fàbregas       -19000000.0                -3.0
# 20801   Cristiano Ronaldo       -18500000.0                 0.0
# 208418        Y. Carrasco       -18500000.0                -2.0
# 183907         J. Boateng       -18000000.0                -3.0
# 176580          L. Suárez       -17000000.0                -1.0

# %%
print('Is the overall improvement based on age?')

# All players that have been in both 2018 and 2019 FIFA
result = data_joined.loc[(data_joined['Name_19'].isnull() != True) & (data_joined['Name_18'].isnull() != True)]

result['Overall Difference'] = result['Overall_19'] - result['Overall_18']
result = result.sort_values(by=['Overall Difference'], ascending=False)
highest_overall = result.head(10)

print('List of players with the highest overall improvement rating along with their age: ')
print(highest_overall[['Name_19', 'Age_19', 'Overall Difference']])

overall_by_age = result.groupby('Age_19').mean()['Overall Difference']

print('\nAverage age of the fastest improving players is', int(overall_by_age.idxmax()))

result.groupby('Age_19').mean()['Overall Difference'].plot.bar(figsize=[20, 10])
# Out:
# Is the overall improvement based on age?
# List of players with the highest overall improvement rating along with their age:
#                Name_19  Age_19  Overall Difference
# ID
# 236527      S. Cáseres    21.0                20.0
# 229880  A. Wan-Bissaka    20.0                19.0
# 240679  T. Koopmeiners    20.0                17.0
# 233267       M. Turner    24.0                17.0
# 236522     E. Brignola    18.0                17.0
# 229406     João Novais    24.0                16.0
# 241184    Junior Firpo    21.0                16.0
# 235794          E. Eze    20.0                16.0
# 235863      M. Varnier    20.0                15.0
# 224263        J. Kenny    21.0                15.0
#
# Average age of the fastest improving players is 18

# %%
print('Which nationality has the best overall average?')

result = data_joined.loc[(data_joined['Name_19'].isnull() != True)]  # All players that are not retired

result = result.groupby('Nationality_19')[['Overall_19', 'Overall_18']].mean()
result['Overall Difference'] = result['Overall_19'] - result['Overall_18']
result = result.sort_values(by=['Overall_19'], ascending=False)

print(result[['Overall_18', 'Overall_19', 'Overall Difference']])
# Out:
# Which nationality has the best overall average?
#                       Overall_18  Overall_19  Overall Difference
# Nationality_19
# Dominican Republic     76.000000   80.000000            4.000000
# Cuba                   77.000000   76.000000           -1.000000
# Mozambique             75.500000   74.500000           -1.000000
# Moldova                74.500000   74.000000           -0.500000
# Central African Rep.   72.000000   73.333333            1.333333
# Chile                  73.290909   73.054545           -0.236364
# Chad                   74.000000   73.000000           -1.000000
# Philippines            68.000000   73.000000            5.000000
# Gabon                  71.333333   72.888889            1.555556
# Brazil                 71.989619   72.719723            0.730104
# Uruguay                71.267327   72.712871            1.445545
# Portugal               72.369650   72.688716            0.319066
# Ukraine                72.058824   72.617647            0.558824
# Croatia                71.647887   72.563380            0.915493
# Russia                 71.062500   72.328125            1.265625
# Cape Verde             70.687500   72.125000            1.437500
# Togo                   70.666667   72.111111            1.444444
# Israel                 71.818182   72.090909            0.272727
# Algeria                71.653061   72.081633            0.428571
# Belarus                73.500000   72.000000           -1.500000
# Ecuador                71.666667   72.000000            0.333333
# Oman                   73.000000   72.000000           -1.000000
# Eritrea                71.000000   72.000000            1.000000
# Paraguay               71.487805   71.951220            0.463415
# Syria                  71.000000   71.857143            0.857143
# Spain                  71.190176   71.812343            0.622166
# Serbia                 71.127660   71.670213            0.542553
# Iran                   68.750000   71.500000            2.750000
# Egypt                  70.434783   71.434783            1.000000
# Peru                   69.291667   71.375000            2.083333
# ...                          ...         ...                 ...
# Azerbaijan             65.666667   65.333333           -0.333333
# St Kitts Nevis         63.500000   65.000000            1.500000
# Canada                 64.476190   64.880952            0.404762
# Montserrat             64.500000   64.750000            0.250000
# Haiti                  63.125000   64.625000            1.500000
# Congo                  63.833333   64.500000            0.666667
# Australia              63.648045   64.435754            0.787709
# Japan                  63.785276   64.407975            0.622699
# Uganda                 63.333333   64.333333            1.000000
# Cyprus                 62.625000   64.125000            1.500000
# New Zealand            62.838710   64.064516            1.225806
# Ethiopia               67.000000   64.000000           -3.000000
# Sudan                  60.000000   64.000000            4.000000
# St Lucia               62.000000   64.000000            2.000000
# Antigua & Barbuda      59.333333   64.000000            4.666667
# Republic of Ireland    62.734615   63.423077            0.688462
# Barbados               62.666667   63.333333            0.666667
# Jordan                 57.000000   63.000000            6.000000
# Puerto Rico            66.000000   63.000000           -3.000000
# Grenada                64.000000   63.000000           -1.000000
# Saudi Arabia           62.399083   62.903670            0.504587
# Faroe Islands          61.000000   62.200000            1.200000
# Guyana                 59.666667   61.666667            2.000000
# Thailand               59.000000   61.500000            2.500000
# Malta                  61.000000   61.000000            0.000000
# Afghanistan            56.333333   60.333333            4.000000
# Uzbekistan             61.000000   60.000000           -1.000000
# Belize                 64.000000   60.000000           -4.000000
# India                  58.523810   59.095238            0.571429
# Hong Kong              54.000000   59.000000            5.000000
#
# [152 rows x 3 columns]

# %%
print('Is the potential of the 2018 dataset correspond to the overall of the 2019 dataset?')

result = data_joined.loc[(data_joined['Name_19'].isnull() != True)] # All players that are not retired
result['Potential was correct'] = result['Potential_18'] == result['Overall_19']
print(result[['Name_19', 'Potential was correct']].head(), '\n')

correct = result.loc[result['Potential was correct'] == True]
correct_percent = (len(correct.index) / len(result.index)) * 100
print(str("%.2f" % correct_percent) + '% of the potential predictions were correct.')

pieData = pd.Series([correct_percent, 100 - correct_percent], index=['Correct', 'Wrong'], name="Potential Predictions")
pieData.plot.pie(figsize=(6, 6))
# Out:
# Is the potential of the 2018 dataset correspond to the overall of the 2019 dataset?
#           Name_19  Potential was correct
# ID
# 16    Luis García                  False
# 41        Iniesta                  False
# 80   E. Belözoğlu                   True
# 657    D. Vaughan                  False
# 768        Felipe                   True
#
# 11.78% of the potential predictions were correct.

# %%
print('Do players with age over 30 have a decrement on their overall?')

result = data_joined.loc[(data_joined['Club_19'].isnull() != True) & (data_joined['Age_18'] > 30)]
result['Overall Decreased'] = result['Overall_19'] < result['Overall_18']
print(result[['Name_18', 'Overall Decreased']].head(), '\n')

had_decrease = result.loc[result['Overall Decreased'] == True]
decrease_percent = (len(had_decrease.index) / len(result.index)) * 100

print(str("%.2f" % decrease_percent) + '% of the players over the age of 30 had a decrease in their overall rating.')

pieData = pd.Series([decrease_percent, 100 - decrease_percent], index=['Decreased', 'Increased'], name="Overall of age > 30")
pieData.plot.pie(figsize=(6, 6))
# Out:
# Do players with age over 30 have a decrement on their overall?
#           Name_18  Overall Decreased
# ID
# 16    Luis García              False
# 41        Iniesta               True
# 80   E. Belözoğlu              False
# 657    D. Vaughan               True
# 768        Felipe              False
#
# 52.18% of the players over the age of 30 had a decrease in their overall rating.

# %%
print('The top 10 ranked players of 2018 are the same with the 2019?\n')
top18 = pd.DataFrame()
top19 = pd.DataFrame()

in_both = []

for i in range(10):
    top18 = top18.append({'Player Name': data18.loc[i]['Name'], 'Overall 2018': data18.loc[i]['Overall']}, ignore_index=True)
    top19 = top19.append({'Player Name': data19.loc[i]['Name'], 'Overall 2019': data19.loc[i]['Overall']}, ignore_index=True)

for i in range(10):
    if top18.iloc[i]['Player Name'] in top19['Player Name'].values:
        in_both.append(top18.iloc[i]['Player Name'])

print(in_both)
print(str(len(in_both)) + ' players appeared on the top 10 charts of both years.\n')

pieData = pd.Series([len(in_both), 10 - len(in_both)], index=['Same', 'Different'], name="Top 10 players")
pieData.plot.pie(figsize=(6, 6))
# Out:
# The top 10 ranked players of 2018 are the same with the 2019?
#
# ['Cristiano Ronaldo', 'L. Messi', 'Neymar Jr', 'L. Suárez', 'De Gea', 'E. Hazard']
# 6 players appeared on the top 10 charts of both years.

# %%
print('Does the change of club affect the value and overall rating of a player?')

result = data_joined.loc[(data_joined['Club_19'].isnull() != True) & (data_joined['Club_19'] != data_joined['Club_18'])]
result['Overall Increased'] = result['Overall_19'] > result['Overall_18']
result['Value Increased'] = result['Value_19'] > result['Value_18']
print(result[['Name_18', 'Overall Increased', 'Value Increased']].head(), '\n')

increased_overall = result.loc[result['Overall Increased'] == True]
increased_value = result.loc[result['Value Increased'] == True]

increased_overall_percent = (len(increased_overall.index) / len(result.index)) * 100
increased_value_percent = (len(increased_value.index) / len(result.index)) * 100

print(str("%.2f" % increased_overall_percent) + '% of the players who changed club had an increase in overall rating.')
print(str("%.2f" % increased_value_percent) + '% of the players who changed club had an increase in value.')

pieDataOverall = [increased_overall_percent, 100 - increased_overall_percent]
pieDataOverall = pd.Series(pieDataOverall, index=['Increased', 'Decreased'], name="Overall")

pieDataValue = [increased_value_percent, 100 - increased_value_percent]
pieDataValue = pd.Series(pieDataValue, index=['Increased', 'Decreased'], name="Value")

plt.figure(0)
pieDataOverall.plot.pie(figsize=(8, 4), autopct='%.2f')
plt.figure(1)
pieDataValue.plot.pie(figsize=(8, 4), autopct='%.2f')

plt.show()
# Out:
# Does the change of club affect the value and overall rating of a player?
#            Name_18  Overall Increased  Value Increased
# ID
# 41         Iniesta              False            False
# 80    E. Belözoğlu              False            False
# 657     D. Vaughan              False            False
# 768         Felipe              False            False
# 1179     G. Buffon              False            False
#
# 44.11% of the players who changed club had an increase in overall rating.
# 43.35% of the players who changed club had an increase in value.

# %%
print('Players that have retired in 2019.\n')

result = data_joined.loc[data_joined['Name_19'].isnull()]
print(result[['Name_18', 'Age_18', 'Position_18']].head())

ageData = result.groupby('Age_18').size()

result = result.groupby('Position_18')['Age_18'].mean()
print('\nList of all positions with the average age of retired players from the position\n')
print(result.head())

plt.figure(0)
ageData.plot.bar()
plt.figure(1)
result.plot.bar(figsize=(20, 8))

plt.show()
# Out:
# Players that have retired in 2019.
#
#            Name_18  Age_18 Position_18
# ID
# 28    Manu Herrera      35          GK
# 591         C. Day      41          GK
# 887      N. Clarke      33          CB
# 1178  P. Cannavaro      36          CB
# 1210     M. Donati      36   CB CM CDM
#
# List of all positions with the average age of retired players from the position
#
# Position_18
# CAM              23.291971
# CAM CDM          28.750000
# CAM CDM CM       25.750000
# CAM CDM LM CM    26.000000
# CAM CDM RB CM    26.000000
# Name: Age_18, dtype: float64
